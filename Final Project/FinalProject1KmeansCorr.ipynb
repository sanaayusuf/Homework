# %%
import os
import sys
import csv
import requests
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
csv_file="framingham.csv"
heart_df=pd.read_csv(csv_file)
heart_df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
heart_df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
from sklearn.datasets.samples_generator import make_blobs

X, _ = make_blobs(n_samples=5
                  
                  
                  
                  
                  00, centers=16,
                            cluster_std=0.50, random_state=0)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=16)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=16, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
predicted_clusters=kmeans.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[ 9.47394854,  5.98986643],
#        [-7.67536305,  2.87588249],
#        [ 0.90435654,  4.22136832],
#        [-8.59203564, -8.29288726],
#        [ 5.81251317,  0.40180731],
#        [-1.40312135,  7.83449791],
#        [-7.13826695,  8.73554231],
#        [ 0.48711244, -1.59626216],
#        [ 9.14815104, -2.22859241],
#        [-0.74453115,  5.52704343],
#        [ 5.49043913,  7.34696904],
#        [-9.73815608,  6.53417085],
#        [-4.70210626,  5.58533541],
#        [ 1.34392814,  8.52219524],
#        [ 2.0607047 ,  1.20235048],
#        [-1.52186751,  2.81145855]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=50, alpha=0.5)

plt.show()

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(heart_df.corr(), fignum=f.number)
plt.xticks(range(heart_df.shape[1]), heart_df.columns, fontsize=14, rotation=45)
plt.yticks(range(heart_df.shape[1]), heart_df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);


plt.matshow(heart_df.corr())
plt.show()
