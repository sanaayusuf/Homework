# %%
import pandas as pd

# %%
df = pd.read_csv('cities.csv')
df.head()
# Out:
#   City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,Max Temp,Wind Speed
# 0  0,jacareacanga,0,BR,1528902000,62,-6.22,-57.76...
# 1  1,kaitangata,100,NZ,1528905304,94,-46.28,169.8...
# 2  2,goulburn,20,AU,1528905078,91,-34.75,149.72,4...
# 3  3,lata,76,IN,1528905305,89,30.78,78.62,59.89,0.94
# 4  4,chokurdakh,0,RU,1528905306,88,70.62,147.9,32...

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,Max Temp,Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0,jacareacanga,0,BR,1528902000,62,-6.22,-57.76...</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1,kaitangata,100,NZ,1528905304,94,-46.28,169.8...</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2,goulburn,20,AU,1528905078,91,-34.75,149.72,4...</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>3,lata,76,IN,1528905305,89,30.78,78.62,59.89,0.94</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>4,chokurdakh,0,RU,1528905306,88,70.62,147.9,32...</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>5,martyush,92,RU,1528905306,94,56.4,61.89,55.0...</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>6,hobart,20,AU,1528902000,87,-42.88,147.33,44....</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <
# ...

# %%
df.to_html('table.html')
