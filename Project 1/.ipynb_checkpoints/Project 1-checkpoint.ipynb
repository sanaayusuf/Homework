# %%
import pandas as pd
import matplotlib as plt
import csv
import os
import numpy as np

# %%
suicide_df = pd.read_csv("master.csv")
economic_df = pd.read_csv("efw_cc.csv")

suicide_df = suicide_df.rename(columns={"gdp_per_capita ($)":"gdp_per_capita"})
suicide_df.head()

#the two data sets have rows that represent different things, 
#and so we need to aggregate one and then create a key to merge them on
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita       generation
# 0             796     Generation X
# 1             796           Silent
# 2             796     Generation X
# 3             796  G.I. Generation
# 4             796          Boomers

# %%
#concatenate "year" and "country" in the suicide rates file to a new column - 'key'
suicide_df['key'] = suicide_df['year'].astype(str) + "|" + suicide_df.country

#aggregate the data, grouped by the new key and reset the index so that the new key is an actual column and not the index
suicide_df_agg = suicide_df.groupby('key').agg({
    "gdp_per_capita": 'mean', 
    "suicides_no": 'sum',
    "suicides/100k pop":'mean'

}).reset_index()

suicide_df_agg.head()

# make sure they both have col called key with that val
# Out:
#                         key  gdp_per_capita  suicides_no  suicides/100k pop
# 0  1985|Antigua and Barbuda            3850            0           0.000000
# 1            1985|Argentina            3264         1988          11.205833
# 2            1985|Australia           12374         1861          13.617500
# 3              1985|Austria            9759         2091          32.067500
# 4              1985|Bahamas           11393            1           0.396667

# %%
#concatenate "year" and "countries" in the economic file to a new column - 'key'
economic_df['key'] = suicide_df['year'].astype(str) + "|" + economic_df.countries

# %%
combined_df = pd.merge(suicide_df_agg,economic_df,how='inner',on='key')
combined_df.head(10)
# Out:
#               key  gdp_per_capita  suicides_no  suicides/100k pop  year  \
# 0  1985|Australia           12374         1861          13.617500  2005
# 1    1985|Austria            9759         2091          32.067500  2005
# 2    1985|Bahamas           11393            1           0.396667  2005
# 3    1985|Bahrain            9980           11           1.676667  2005
# 4   1985|Barbados            6137            7           5.143333  2005
# 5    1985|Belgium            9356         2281          27.670000  2005
# 6    1985|Ecuador            2238          393           6.876667  1975
# 7     1985|France           10765        12501          29.075000  2000
# 8      1985|Malta            3639            2           0.730000  2002
# 9  1985|Mauritius            1223          104          11.927500  2002
#
#   ISO_code  countries  ECONOMIC FREEDOM  rank  quartile  ...  3_sound_money  \
# 0      AUS  Australia              8.07  10.0       1.0  ...       9.440071
# 1      AUT    Austria              7.85  14.0       1.0  ...       9.554901
# 2      BHS    Bahamas              7.38  37.0       2.0  ...       6.815573
# 3      BHR    Bahrain              6.89  68.0       2.0  ...       8.816727
# 4      BRD   Barbados              6.31  93.0       3.0  ...       6.286198
# 5      BEL    Belgium              7.41  35.0       1.0  ...       9.529653
# 6      ECU    Ecuador              5.31  38.0       3.0  ...       7.429392
# 7      FRA     France              7.47  29.0       1.0  ...       9.586504
# 8      MLT      Malta              6.88  54.0       2.0  ...       6.965955
# 9      MUS  Mauritius              7.29  37.0       2.0  ...       9.491014
#
#    4a_tariffs  4b_regulatory_trade_barriers  4c_black_market  \
# 0    8.426222                      8.176821             10.0
# 1    8.393422                      8.386565             10.0
# 2    4.261600                           NaN             10.0
# 3    8.373511                      7.587719             10.0
# 4    5.626678                      5.208333             10.0
# 5    8.393422                      8.069216             10.0
# 6    4.066667                           NaN              9.0
# 7    9.180390                      8.709175             10.0
# 8    8.486667                      7.833333             10.0
# 9    4.286667                      6.666667             10.0
#
#    4d_control_movement_capital_ppl   4_trade  5a_credit_market_reg  \
# 0                         3.324660  7.481926             10.000000
# 1                         5.803007  8.145749              9.754512
# 2                         4.769231  6.343610              9.784213
# 3                         4.630574  7.647951              9.430436
# 4                         5.806095  6.660277              8.339361
# 5                         6.627103  8.272435              9.665691
# 6                         2.000000  5.022222              5.745746
# 7                         8.007803  8.974342              9.785249
# 8                         4.051282  7.592821              8.620487
# 9                         6.127167  6.770125              8.827949
#
#    5b_labor_market_reg  5c_business_reg  5_regulation
# 0             8.359913         7.291367      8.550427
# 1             5.905489         7.212824      7.624275
# 2                  NaN              NaN      7.424451
# 3             7.032164         4.825916      7.096172
# 4             7.212308         5.027839      6.859836
# 5             6.640401         7.572510      7.959534
# 6                  NaN              NaN           NaN
# 7             5.326292         8.362891      7.824811
# 8             6.666667         5.849206      7.045453
# 9             6.964769         5.935614      7.242777
#
# [10 rows x 40 columns]

# %%
#remove key column because it's not needed
combined_df = combined_df.drop(columns="key")
combined_df.head()
# Out:
#    gdp_per_capita  suicides_no  suicides/100k pop  year ISO_code  countries  \
# 0           12374         1861          13.617500  2005      AUS  Australia
# 1            9759         2091          32.067500  2005      AUT    Austria
# 2           11393            1           0.396667  2005      BHS    Bahamas
# 3            9980           11           1.676667  2005      BHR    Bahrain
# 4            6137            7           5.143333  2005      BRD   Barbados
#
#    ECONOMIC FREEDOM  rank  quartile  1a_government_consumption  ...  \
# 0              8.07  10.0       1.0                   4.719140  ...
# 1              7.85  14.0       1.0                   4.577317  ...
# 2              7.38  37.0       2.0                   6.460052  ...
# 3              6.89  68.0       2.0                   2.943336  ...
# 4              6.31  93.0       3.0                   4.435294  ...
#
#    3_sound_money  4a_tariffs  4b_regulatory_trade_barriers  4c_black_market  \
# 0       9.440071    8.426222                      8.176821             10.0
# 1       9.554901    8.393422                      8.386565             10.0
# 2       6.815573    4.261600                           NaN             10.0
# 3       8.816727    8.373511                      7.587719             10.0
# 4       6.286198    5.626678                      5.208333             10.0
#
#    4d_control_movement_capital_ppl   4_trade  5a_credit_market_reg  \
# 0                         3.324660  7.481926             10.000000
# 1                         5.803007  8.145749              9.754512
# 2                         4.769231  6.343610              9.784213
# 3                         4.630574  7.647951              9.430436
# 4                         5.806095  6.660277              8.339361
#
#    5b_labor_market_reg  5c_business_reg  5_regulation
# 0             8.359913         7.291367      8.550427
# 1             5.905489         7.212824      7.624275
# 2                  NaN              NaN      7.424451
# 3             7.032164         4.825916      7.096172
# 4             7.212308         5.027839      6.859836
#
# [5 rows x 39 columns]

# %%
#create a final df for analysis that includes just the columns we need, with "countries" as the first column for posterity
final_df = combined_df[['countries','year','gdp_per_capita','suicides_no','suicides/100k pop','ECONOMIC FREEDOM',
                        'rank','4a_tariffs','4c_black_market','5b_labor_market_reg',
                        '5_regulation','1d_top_marg_tax_rate','2d_military_interference','2e_integrity_legal_system','5_regulation']]
final_df.head(10)
# Out:
#    countries  year  gdp_per_capita  suicides_no  suicides/100k pop  \
# 0  Australia  2005           12374         1861          13.617500
# 1    Austria  2005            9759         2091          32.067500
# 2    Bahamas  2005           11393            1           0.396667
# 3    Bahrain  2005            9980           11           1.676667
# 4   Barbados  2005            6137            7           5.143333
# 5    Belgium  2005            9356         2281          27.670000
# 6    Ecuador  1975            2238          393           6.876667
# 7     France  2000           10765        12501          29.075000
# 8      Malta  2002            3639            2           0.730000
# 9  Mauritius  2002            1223          104          11.927500
#
#    ECONOMIC FREEDOM  rank  4a_tariffs  4c_black_market  5b_labor_market_reg  \
# 0              8.07  10.0    8.426222             10.0             8.359913
# 1              7.85  14.0    8.393422             10.0             5.905489
# 2              7.38  37.0    4.261600             10.0                  NaN
# 3              6.89  68.0    8.373511             10.0             7.032164
# 4              6.31  93.0    5.626678             10.0             7.212308
# 5              7.41  35.0    8.393422             10.0             6.640401
# 6              5.31  38.0    4.066667              9.0                  NaN
# 7              7.47  29.0    9.180390             10.0             5.326292
# 8              6.88  54.0    8.486667             10.0             6.666667
# 9              7.29  37.0    4.286667             10.0             6.964769
#
#    5_regulation  1d_top_marg_tax_rate  2d_military_interference  \
# 0      8.550427                   4.0                 10.000000
# 1      7.624275                   3.5                 10.000000
# 2      7.424451                  10.0                 10.000000
# 3      7.096172                  10.0                  5.000000
# 4      6.859836                   3.5                  9.400000
# 5      7.959534                   1.0                 10.000000
# 6           NaN                   5.0                       NaN
# 7      7.824811                   1.0                  8.333333
# 8      7.045453                   7.0                 10.000000
# 9      7.242777                   8.0                 10.000000
#
#    2e_integrity_legal_system  5_regulation
# 0                   9.791667      8.550427
# 1                  10.000000      7.624275
# 2                   7.500000      7.424451
# 3                   8.333333      7.096172
# 4                        NaN      6.859836
# 5                   8.333333      7.959534
# 6                        NaN           NaN
# 7                   8.333333      7.824811
# 8                   8.333333      7.045453
# 9                   6.700000      7.242777

# %%
#remove any row with NaN
final_df_clean = final_df.dropna(how="any")
final_df_clean.head()
# Out:
#    countries  year  gdp_per_capita  suicides_no  suicides/100k pop  \
# 0  Australia  2005           12374         1861          13.617500
# 1    Austria  2005            9759         2091          32.067500
# 3    Bahrain  2005            9980           11           1.676667
# 5    Belgium  2005            9356         2281          27.670000
# 7     France  2000           10765        12501          29.075000
#
#    ECONOMIC FREEDOM  rank  4a_tariffs  4c_black_market  5b_labor_market_reg  \
# 0              8.07  10.0    8.426222             10.0             8.359913
# 1              7.85  14.0    8.393422             10.0             5.905489
# 3              6.89  68.0    8.373511             10.0             7.032164
# 5              7.41  35.0    8.393422             10.0             6.640401
# 7              7.47  29.0    9.180390             10.0             5.326292
#
#    5_regulation  1d_top_marg_tax_rate  2d_military_interference  \
# 0      8.550427                   4.0                 10.000000
# 1      7.624275                   3.5                 10.000000
# 3      7.096172                  10.0                  5.000000
# 5      7.959534                   1.0                 10.000000
# 7      7.824811                   1.0                  8.333333
#
#    2e_integrity_legal_system  5_regulation
# 0                   9.791667      8.550427
# 1                  10.000000      7.624275
# 3                   8.333333      7.096172
# 5                   8.333333      7.959534
# 7                   8.333333      7.824811

# %%
#final dataframe grouped by year first to see which year has the most rows with data
final_df_clean.groupby(['year']).agg({
    'countries':'count'
})
# Out:
#       countries
# year
# 1995         32
# 2000         49
# 2001         54
# 2002         52
# 2003         45
# 2004         58
# 2005         44
# 2006         63
# 2007         53
# 2008         59
# 2009         54
# 2010         56
# 2011         63
# 2012         55
# 2013         50
# 2014         56
# 2015         53
# 2016         55

# %%
#which country has the most years worth of data for a time-series analysis?
final_df_clean.groupby(['countries']).agg({
    'year':'count'
})
# Out:
#                 year
# countries
# Albania            8
# Argentina         18
# Armenia            9
# Australia         17
# Austria           18
# Azerbaijan         9
# Bahamas            7
# Bahrain           11
# Barbados           2
# Belgium           18
# Brazil            18
# Bulgaria          17
# Canada            18
# Chile             18
# Colombia          18
# Costa Rica        17
# Croatia           11
# Cyprus             7
# Denmark           13
# Ecuador           17
# El Salvador       13
# Estonia           10
# Finland           17
# France            17
# Germany           15
# Greece            17
# Guatemala         16
# Guyana            14
# Hungary           15
# Iceland           18
# ...              ...
# Malta             17
# Mauritius          5
# Mexico            18
# Netherlands       18
# New Zealand       17
# Nicaragua          4
# Norway            16
# Oman               1
# Panama            14
# Paraguay          15
# Philippines       10
# Poland            13
# Portugal          16
# Qatar              2
# Romania           15
# Serbia             8
# Singapore         18
# Slovenia          13
# South Africa      11
# Spain             18
# Sri Lanka          8
# Suriname           4
# Sweden            16
# Switzerland       14
# Thailand          15
# Turkey             3
# Ukraine           16
# United Kingdom    18
# United States     18
# Uruguay           16
#
# [70 rows x 1 columns]

# %%
#compare the highest economic freedom to lowest economic freedom-
#compare highest suicide rates to lowest suicide rates
# 2 line graph

# %%
my_df = final_df_clean[final_df_clean['year'] == 2016].groupby('countries').agg({'suicides/100k pop':'mean',
                                                                                 '2d_military_interference':'mean'
                                                                                 
                                                                            
    
})

my_df.head(10)
# Out:
#            suicides/100k pop  2d_military_interference
# countries
# Albania             2.654167                  8.333333
# Argentina          12.081667                  7.500000
# Australia          15.735000                 10.000000
# Austria            33.823333                 10.000000
# Bahamas             1.132500                 10.000000
# Bahrain             2.140000                  5.000000
# Belgium            23.650000                 10.000000
# Brazil              5.446667                  6.666667
# Bulgaria           24.374167                  8.333333
# Canada             14.248333                 10.000000

# %%
#ten military interference-2016 (max/min)
#graph
#second graph follow up  

max_df=my_df.nlargest(10,['2d_military_interference','suicides/100k pop'])

max_df.head(10)
# Out:
#              suicides/100k pop  2d_military_interference
# countries
# Hungary              44.650833                      10.0
# Austria              33.823333                      10.0
# Finland              27.750000                      10.0
# Belgium              23.650000                      10.0
# Switzerland          22.183333                      10.0
# Germany              19.625000                      10.0
# Luxembourg           19.104167                      10.0
# New Zealand          16.523333                      10.0
# Australia            15.735000                      10.0
# Canada               14.248333                      10.0

# %%
df = pd.DataFrame(max_df)

df.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5720c3d273e9> in <module>
#       3 df.plot(kind='bar')
#       4
# ----> 5 max_df_title('Top Ten Suicide Vs. Military Interference')
#
# NameError: name 'max_df_title' is not defined

# %%
my_df.nsmallest(10,['2d_military_interference','suicides/100k pop'])
